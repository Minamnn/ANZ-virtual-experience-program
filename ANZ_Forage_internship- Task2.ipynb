# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
df = pd.read_csv("/content/drive/My Drive/ANZdata.csv")

# %%
df[:5]
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# 0            NaN      Diana  ...   26         Ashmore            QLD
# 1            NaN      Diana  ...   26          Sydney            NSW
# 2            NaN    Michael  ...   38          Sydney            NSW
# 3            NaN     Rhonda  ...   40         Buderim            QLD
# 4            NaN      Diana  ...   26   Mermaid Beach            QLD
#
#                      extraction amount                    transaction_id  \
# 0  2018-08-01T01:01:15.000+0000  16.25  a623070bfead4541a6b0fff8a09e706c
# 1  2018-08-01T01:13:45.000+0000  14.19  13270a2a902145da9db4c951e04b51b9
# 2  2018-08-01T01:26:15.000+0000   6.42  feb79e7ecd7048a5a36ec889d1a94270
# 3  2018-08-01T01:38:45.000+0000  40.90  2698170da3704fd981b15e64a006079e
# 4  2018-08-01T01:51:15.000+0000   3.25  329adf79878c4cf0aeb4188b4691c266
#
#      country     customer_id merchant_long_lat movement
# 0  Australia  CUS-2487424745     153.38 -27.99    debit
# 1  Australia  CUS-2487424745     151.21 -33.87    debit
# 2  Australia  CUS-2142601169     151.21 -33.87    debit
# 3  Australia  CUS-1614226872     153.05 -26.68    debit
# 4  Australia  CUS-2487424745     153.44 -28.06    debit
#
# [5 rows x 23 columns]

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of            status  card_present_flag bpay_biller_code         account  \
# 0      authorized                1.0              NaN  ACC-1598451071
# 1      authorized                0.0              NaN  ACC-1598451071
# 2      authorized                1.0              NaN  ACC-1222300524
# 3      authorized                1.0              NaN  ACC-1037050564
# 4      authorized                1.0              NaN  ACC-1598451071
# ...           ...                ...              ...             ...
# 12038  authorized                0.0              NaN  ACC-3021093232
# 12039  authorized                1.0              NaN  ACC-1608363396
# 12040  authorized                1.0              NaN  ACC-3827517394
# 12041  authorized                1.0              NaN  ACC-2920611728
# 12042  authorized                1.0              NaN  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 0          AUD  153.41 -27.95             POS
# 1          AUD  153.41 -27.95       SALES-POS
# 2          AUD  151.23 -33.94             POS
# 3          AUD  153.10 -27.66       SALES-POS
# 4          AUD  153.41 -27.95       SALES-POS
# ...        ...            ...             ...
# 12038      AUD  149.83 -29.47             POS
# 12039      AUD  151.22 -33.87       SALES-POS
# 12040      AUD  151.12 -33.89             POS
# 12041      AUD  144.96 -37.76       SALES-POS
# 12042      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id  merchant_code first_name  ...  \
# 0      81c48296-73be-44a7-befa-d053f48ce7cd            NaN      Diana  ...
# 1      830a451c-316e-4a6a-bf25-e37caedca49e            NaN      Diana  ...
# 2      835c231d-8cdf-4e96-859d-e9d571760cf0            NaN    Michael  ...
# 3      48514682-c78a-4a88-b0da-2d6302e64673            NaN     Rhonda  ...
# 4      b4e02c10-0852-4273-b8fd-7b3395e32eb0            NaN      Diana  ...
# ...                                     ...            ...        ...  ...
# 12038  32aa73dc-b7c2-4161-b14d-6271b96ce792            NaN    Melissa  ...
# 12039  296a0500-8552-48ac-ac81-ec37065b568e            NaN     Robert  ...
# 12040  e5975ab4-08f7-4725-a369-24cc0e35ed6e            NaN      Craig  ...
# 12041  af49051a-591d-4b08-bd3c-27730b70ed37            NaN      Tyler  ...
# 12042  f31f4b14-2040-40ec-a120-b141bb274cbd            NaN       Ryan  ...
#
#        age merchant_suburb merchant_state                    extraction  \
# 0       26         Ashmore            QLD  2018-08-01T01:01:15.000+0000
# 1       26          Sydney            NSW  2018-08-01T01:13:45.000+0000
# 2       38          Sydney            NSW  2018-08-01T01:26:15.000+0000
# 3       40         Buderim            QLD  2018-08-01T01:38:45.000+0000
# 4       26   Mermaid Beach            QLD  2018-08-01T01:51:15.000+0000
# ...    ...             ...            ...                           ...
# 12038   30        Ringwood            VIC  2018-10-31T23:09:06.000+0000
# 12039   20          Casula            NSW  2018-10-31T23:21:46.000+0000
# 12040   28      Kings Park            NSW  2018-10-31T23:34:25.000+0000
# 12041   69        Oakleigh            VIC  2018-10-31T23:47:05.000+0000
# 12042   31          Mascot            NSW  2018-10-31T23:59:44.000+0000
#
#       amount                    transaction_id    country     customer_id  \
# 0      16.25  a623070bfead4541a6b0fff8a09e706c  Australia  CUS-2487424745
# 1      14.19  13270a2a902145da9db4c951e04b51b9  Australia  CUS-2487424745
# 2       6.42  feb79e7ecd7048a5a36ec889d1a94270  Australia  CUS-2142601169
# 3      40.90  2698170da3704fd981b15e64a006079e  Australia  CUS-1614226872
# 4       3.25  329adf79878c4cf0aeb4188b4691c266  Australia  CUS-2487424745
# ...      ...                               ...        ...             ...
# 12038   9.79  f2e3e695c2ee4c50a4c8747f852cbe2e  Australia    CUS-55310383
# 12039  63.87  56e147e5485f4683b9076fcaaed76640  Australia  CUS-2688605418
# 12040  43.96  2fdd4681827343f6af2e6519644a684a  Australia  CUS-2663907001
# 12041  30.77  74aa9cd7e4af4c6d9cd7dbd28e9aedc9  Australia  CUS-1388323263
# 12042  22.36  6d5218e04e8040b9996850ce11a19426  Australia  CUS-3129499595
#
#       merchant_long_lat movement
# 0         153.38 -27.99    debit
# 1         151.21 -33.87    debit
# 2         151.21 -33.87    debit
# 3         153.05 -26.68    debit
# 4         153.44 -28.06    debit
# ...                 ...      ...
# 12038     145.23 -37.81    debit
# 12039     150.88 -33.96    debit
# 12040     150.92 -33.74    debit
# 12041     145.09 -37.91    debit
# 12042     151.19 -33.93    debit
#
# [12043 rows x 23 columns]>

# %%
df= df.replace(np.nan, 0)
df
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 0      authorized                1.0                0  ACC-1598451071
# 1      authorized                0.0                0  ACC-1598451071
# 2      authorized                1.0                0  ACC-1222300524
# 3      authorized                1.0                0  ACC-1037050564
# 4      authorized                1.0                0  ACC-1598451071
# ...           ...                ...              ...             ...
# 12038  authorized                0.0                0  ACC-3021093232
# 12039  authorized                1.0                0  ACC-1608363396
# 12040  authorized                1.0                0  ACC-3827517394
# 12041  authorized                1.0                0  ACC-2920611728
# 12042  authorized                1.0                0  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 0          AUD  153.41 -27.95             POS
# 1          AUD  153.41 -27.95       SALES-POS
# 2          AUD  151.23 -33.94             POS
# 3          AUD  153.10 -27.66       SALES-POS
# 4          AUD  153.41 -27.95       SALES-POS
# ...        ...            ...             ...
# 12038      AUD  149.83 -29.47             POS
# 12039      AUD  151.22 -33.87       SALES-POS
# 12040      AUD  151.12 -33.89             POS
# 12041      AUD  144.96 -37.76       SALES-POS
# 12042      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id  merchant_code first_name  ...  \
# 0      81c48296-73be-44a7-befa-d053f48ce7cd            0.0      Diana  ...
# 1      830a451c-316e-4a6a-bf25-e37caedca49e            0.0      Diana  ...
# 2      835c231d-8cdf-4e96-859d-e9d571760cf0            0.0    Michael  ...
# 3      48514682-c78a-4a88-b0da-2d6302e64673            0.0     Rhonda  ...
# 4      b4e02c10-0852-4273-b8fd-7b3395e32eb0            0.0      Diana  ...
# ...                                     ...            ...        ...  ...
# 12038  32aa73dc-b7c2-4161-b14d-6271b96ce792            0.0    Melissa  ...
# 12039  296a0500-8552-48ac-ac81-ec37065b568e            0.0     Robert  ...
# 12040  e5975ab4-08f7-4725-a369-24cc0e35ed6e            0.0      Craig  ...
# 12041  af49051a-591d-4b08-bd3c-27730b70ed37            0.0      Tyler  ...
# 12042  f31f4b14-2040-40ec-a120-b141bb274cbd            0.0       Ryan  ...
#
#        age merchant_suburb merchant_state                    extraction  \
# 0       26         Ashmore            QLD  2018-08-01T01:01:15.000+0000
# 1       26          Sydney            NSW  2018-08-01T01:13:45.000+0000
# 2       38          Sydney            NSW  2018-08-01T01:26:15.000+0000
# 3       40         Buderim            QLD  2018-08-01T01:38:45.000+0000
# 4       26   Mermaid Beach            QLD  2018-08-01T01:51:15.000+0000
# ...    ...             ...            ...                           ...
# 12038   30        Ringwood            VIC  2018-10-31T23:09:06.000+0000
# 12039   20          Casula            NSW  2018-10-31T23:21:46.000+0000
# 12040   28      Kings Park            NSW  2018-10-31T23:34:25.000+0000
# 12041   69        Oakleigh            VIC  2018-10-31T23:47:05.000+0000
# 12042   31          Mascot            NSW  2018-10-31T23:59:44.000+0000
#
#       amount                    transaction_id    country     customer_id  \
# 0      16.25  a623070bfead4541a6b0fff8a09e706c  Australia  CUS-2487424745
# 1      14.19  13270a2a902145da9db4c951e04b51b9  Australia  CUS-2487424745
# 2       6.42  feb79e7ecd7048a5a36ec889d1a94270  Australia  CUS-2142601169
# 3      40.90  2698170da3704fd981b15e64a006079e  Australia  CUS-1614226872
# 4       3.25  329adf79878c4cf0aeb4188b4691c266  Australia  CUS-2487424745
# ...      ...                               ...        ...             ...
# 12038   9.79  f2e3e695c2ee4c50a4c8747f852cbe2e  Australia    CUS-55310383
# 12039  63.87  56e147e5485f4683b9076fcaaed76640  Australia  CUS-2688605418
# 12040  43.96  2fdd4681827343f6af2e6519644a684a  Australia  CUS-2663907001
# 12041  30.77  74aa9cd7e4af4c6d9cd7dbd28e9aedc9  Australia  CUS-1388323263
# 12042  22.36  6d5218e04e8040b9996850ce11a19426  Australia  CUS-3129499595
#
#       merchant_long_lat movement
# 0         153.38 -27.99    debit
# 1         151.21 -33.87    debit
# 2         151.21 -33.87    debit
# 3         153.05 -26.68    debit
# 4         153.44 -28.06    debit
# ...                 ...      ...
# 12038     145.23 -37.81    debit
# 12039     150.88 -33.96    debit
# 12040     150.92 -33.74    debit
# 12041     145.09 -37.91    debit
# 12042     151.19 -33.93    debit
#
# [12043 rows x 23 columns]

# %%
import matplotlib.pyplot as plt

df.plot(x='amount', y='age', style='o')  
plt.title('amount vs age')  
plt.xlabel('amount')  
plt.ylabel('age')  
plt.show()

# %%
df_query= df.loc[(df['age']>=25),['first_name','age', 'extraction']]
df_query
# Out:
#       first_name  age                    extraction
# 0          Diana   26  2018-08-01T01:01:15.000+0000
# 1          Diana   26  2018-08-01T01:13:45.000+0000
# 2        Michael   38  2018-08-01T01:26:15.000+0000
# 3         Rhonda   40  2018-08-01T01:38:45.000+0000
# 4          Diana   26  2018-08-01T01:51:15.000+0000
# ...          ...  ...                           ...
# 12037    Kenneth   29  2018-10-31T23:00:00.000+0000
# 12038    Melissa   30  2018-10-31T23:09:06.000+0000
# 12040      Craig   28  2018-10-31T23:34:25.000+0000
# 12041      Tyler   69  2018-10-31T23:47:05.000+0000
# 12042       Ryan   31  2018-10-31T23:59:44.000+0000
#
# [7970 rows x 3 columns]

# %%
query = df.query('amount >= 20.0 & age < 60')
query
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 3      authorized                1.0                0  ACC-1037050564
# 5          posted                0.0                0  ACC-1608363396
# 6      authorized                1.0                0  ACC-2776252858
# 9          posted                0.0                0   ACC-602667573
# 10         posted                0.0                0  ACC-2171593283
# ...           ...                ...              ...             ...
# 12036      posted                0.0                0  ACC-1349834573
# 12037      posted                0.0                0   ACC-240804743
# 12039  authorized                1.0                0  ACC-1608363396
# 12040  authorized                1.0                0  ACC-3827517394
# 12042  authorized                1.0                0  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 3          AUD  153.10 -27.66       SALES-POS
# 5          AUD  151.22 -33.87         PAYMENT
# 6          AUD  144.95 -37.76       SALES-POS
# 9          AUD  151.23 -33.96      INTER BANK
# 10         AUD  146.94 -36.04         PAYMENT
# ...        ...            ...             ...
# 12036      AUD  145.17 -37.84         PAYMENT
# 12037      AUD  121.48 -30.75         PAYMENT
# 12039      AUD  151.22 -33.87       SALES-POS
# 12040      AUD  151.12 -33.89             POS
# 12042      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id  merchant_code first_name  ...  \
# 3      48514682-c78a-4a88-b0da-2d6302e64673            0.0     Rhonda  ...
# 5                                         0            0.0     Robert  ...
# 6      3aa18033-a0a9-4190-a117-b7caaf4d07e3            0.0    Kristin  ...
# 9                                         0            0.0    Michael  ...
# 10                                        0            0.0   Fernando  ...
# ...                                     ...            ...        ...  ...
# 12036                                     0            0.0    Matthew  ...
# 12037                                     0            0.0    Kenneth  ...
# 12039  296a0500-8552-48ac-ac81-ec37065b568e            0.0     Robert  ...
# 12040  e5975ab4-08f7-4725-a369-24cc0e35ed6e            0.0      Craig  ...
# 12042  f31f4b14-2040-40ec-a120-b141bb274cbd            0.0       Ryan  ...
#
#        age merchant_suburb merchant_state                    extraction  \
# 3       40         Buderim            QLD  2018-08-01T01:38:45.000+0000
# 5       20               0              0  2018-08-01T02:00:00.000+0000
# 6       43        Kalkallo            VIC  2018-08-01T02:23:04.000+0000
# 9       40               0              0  2018-08-01T06:00:00.000+0000
# 10      19               0              0  2018-08-01T06:00:00.000+0000
# ...    ...             ...            ...                           ...
# 12036   39               0              0  2018-10-31T23:00:00.000+0000
# 12037   29               0              0  2018-10-31T23:00:00.000+0000
# 12039   20          Casula            NSW  2018-10-31T23:21:46.000+0000
# 12040   28      Kings Park            NSW  2018-10-31T23:34:25.000+0000
# 12042   31          Mascot            NSW  2018-10-31T23:59:44.000+0000
#
#        amount                    transaction_id    country     customer_id  \
# 3       40.90  2698170da3704fd981b15e64a006079e  Australia  CUS-1614226872
# 5      163.00  1005b48a6eda4ffd85e9b649dc9467d3  Australia  CUS-2688605418
# 6       61.06  b79ca208099c4c28aa5dae966096d842  Australia  CUS-4123612273
# 9       21.00  798a77869014441b840a7a8a23408332  Australia  CUS-2031327464
# 10      27.00  baff17b27b2643c48c84fca7129e9611  Australia  CUS-2317998716
# ...       ...                               ...        ...             ...
# 12036   32.00  df15d6f039554dcbb3ca02631ce22068  Australia  CUS-1790886359
# 12037   39.00  c7bc398b9eb04e73933dc6d5a7beae0b  Australia   CUS-261674136
# 12039   63.87  56e147e5485f4683b9076fcaaed76640  Australia  CUS-2688605418
# 12040   43.96  2fdd4681827343f6af2e6519644a684a  Australia  CUS-2663907001
# 12042   22.36  6d5218e04e8040b9996850ce11a19426  Australia  CUS-3129499595
#
#       merchant_long_lat movement
# 3         153.05 -26.68    debit
# 5                     0    debit
# 6         144.95 -37.53    debit
# 9                     0    debit
# 10                    0    debit
# ...                 ...      ...
# 12036                 0    debit
# 12037                 0    debit
# 12039     150.88 -33.96    debit
# 12040     150.92 -33.74    debit
# 12042     151.19 -33.93    debit
#
# [7797 rows x 23 columns]

# %%
query3= df[(df['amount']>=20.0) & (df['age']>20) & (df['status'] == 'authorized') & (df['first_name'].str.startswith('R'))][['first_name','age','status', 'amount']]
query3
# Out:
#       first_name  age      status  amount
# 3         Rhonda   40  authorized   40.90
# 30        Rhonda   40  authorized   45.12
# 36       Richard   24  authorized   87.03
# 59        Ronald   25  authorized   27.39
# 107         Ryan   31  authorized   93.79
# ...          ...  ...         ...     ...
# 12029      Renee   38  authorized   93.46
# 12030       Ryan   31  authorized  234.90
# 12031       Ryan   31  authorized   70.51
# 12033     Ronald   25  authorized   26.59
# 12042       Ryan   31  authorized   22.36
#
# [572 rows x 4 columns]

# %%
query4= df[(df.amount > 100.0) & (df.card_present_flag == 1.0)]
query4
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 49     authorized                1.0                0  ACC-2615038700
# 56     authorized                1.0                0  ACC-2615038700
# 164    authorized                1.0                0  ACC-3879258709
# 226    authorized                1.0                0  ACC-3536132544
# 236    authorized                1.0                0  ACC-3326339947
# ...           ...                ...              ...             ...
# 11947  authorized                1.0                0  ACC-2171593283
# 11958  authorized                1.0                0  ACC-2897221629
# 11973  authorized                1.0                0  ACC-1344825761
# 11992  authorized                1.0                0   ACC-819621312
# 12030  authorized                1.0                0  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 49         AUD  145.35 -38.03             POS
# 56         AUD  145.35 -38.03       SALES-POS
# 164        AUD  143.83 -37.66             POS
# 226        AUD  144.93 -37.79             POS
# 236        AUD  151.18 -33.80             POS
# ...        ...            ...             ...
# 11947      AUD  146.94 -36.04       SALES-POS
# 11958      AUD  150.90 -34.37             POS
# 11973      AUD  151.09 -33.91             POS
# 11992      AUD  145.04 -37.85       SALES-POS
# 12030      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id  merchant_code first_name  ...  \
# 49     07df1647-c4aa-479b-a7c2-1952aafbc6bb            0.0      Emily  ...
# 56     54b35383-6f69-453b-be91-b63005b97135            0.0      Emily  ...
# 164    42ade571-5972-4160-9ecb-e0162a305fee            0.0    Natasha  ...
# 226    ec141b19-89cc-42cb-9c0b-4493ab9a80b5            0.0    Heather  ...
# 236    feda5c3b-b971-4d0f-bd4e-00910b13a027            0.0       Eric  ...
# ...                                     ...            ...        ...  ...
# 11947  789f4f77-735c-41d4-b2dc-b9c4b5bee7d6            0.0   Fernando  ...
# 11958  d5635ec1-7e0d-40c1-a0ec-f560ad82d400            0.0      Scott  ...
# 11973  ddce202f-e1d4-4008-b949-c0bbd793eb2f            0.0      Sarah  ...
# 11992  7b4deb71-0e46-4da6-b2fa-7c718273f157            0.0    Michele  ...
# 12030  976e9595-fdf4-4662-aaf2-476681a0291f            0.0       Ryan  ...
#
#        age  merchant_suburb merchant_state                    extraction  \
# 49      43  Dandenong South            VIC  2018-08-01T10:55:42.000+0000
# 56      43    Mossman Gorge            QLD  2018-08-01T11:31:58.000+0000
# 164     40          Belrose            NSW  2018-08-02T08:16:34.000+0000
# 226     41        Parkville            VIC  2018-08-02T15:10:15.000+0000
# 236     22       Parramatta            NSW  2018-08-02T16:07:12.000+0000
# ...    ...              ...            ...                           ...
# 11947   19           Sydney            NSW  2018-10-31T10:47:11.000+0000
# 11958   23        East Ryde            NSW  2018-10-31T11:49:44.000+0000
# 11973   46      Surry Hills            NSW  2018-10-31T13:34:20.000+0000
# 11992   30    Mount Gambier             SA  2018-10-31T15:53:23.000+0000
# 12030   31           Sydney            NSW  2018-10-31T21:40:19.000+0000
#
#        amount                    transaction_id    country     customer_id  \
# 49     937.73  44806f4994f249e9a7411776530e0ff6  Australia  CUS-3255104878
# 56     501.67  3972bef449b54d3b9db6bc77e1c8d165  Australia  CUS-3255104878
# 164    108.65  da7d50bf71c14c7f884a3328cff0467b  Australia   CUS-527400765
# 226    107.67  02e98a1a6fb94e2583dfd8a84bd152bc  Australia  CUS-2348881191
# 236    263.44  b649dd03b4b64f4b83de005e89d35ab3  Australia   CUS-326006476
# ...       ...                               ...        ...             ...
# 11947  107.97  fbfac76b8166477c95812306069e9e1c  Australia  CUS-2317998716
# 11958  348.21  e4ea3360d90840a09a72ba2a34271618  Australia   CUS-511326734
# 11973  263.64  dc000af1a59b4892b23478446e9435e0  Australia  CUS-1499065773
# 11992  652.93  deea499dc5644025a0939e56983a7a13  Australia  CUS-1271030853
# 12030  234.90  9b85bc8e0da848fab4ecbe176d6fabb0  Australia  CUS-3129499595
#
#       merchant_long_lat movement
# 49        145.21 -38.03    debit
# 56        145.35 -16.47    debit
# 164        151.21 -33.7    debit
# 226        144.96 -37.8    debit
# 236       150.99 -33.82    debit
# ...                 ...      ...
# 11947     151.18 -33.94    debit
# 11958     151.13 -33.81    debit
# 11973     151.21 -33.88    debit
# 11992     140.78 -37.83    debit
# 12030      151.2 -33.87    debit
#
# [305 rows x 23 columns]

# %%
query= df[~df.first_name.str.startswith('R') & ((df.card_present_flag == 1.0))]
query[:10]
# Out:
#         status  card_present_flag bpay_biller_code         account currency  \
# 0   authorized                1.0                0  ACC-1598451071      AUD
# 2   authorized                1.0                0  ACC-1222300524      AUD
# 4   authorized                1.0                0  ACC-1598451071      AUD
# 6   authorized                1.0                0  ACC-2776252858      AUD
# 7   authorized                1.0                0  ACC-2776252858      AUD
# 8   authorized                1.0                0   ACC-182446574      AUD
# 12  authorized                1.0                0   ACC-182446574      AUD
# 15  authorized                1.0                0  ACC-1903037542      AUD
# 19  authorized                1.0                0  ACC-4258502723      AUD
# 20  authorized                1.0                0  ACC-1598451071      AUD
#
#          long_lat txn_description                           merchant_id  \
# 0   153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 2   151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 4   153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
# 6   144.95 -37.76       SALES-POS  3aa18033-a0a9-4190-a117-b7caaf4d07e3
# 7   144.95 -37.76             POS  ee58145d-26e8-4b01-9cd9-62378014f21d
# 8   116.06 -32.00             POS  cfbf535e-caa8-499f-9d41-bbdc2b836d85
# 12  116.06 -32.00       SALES-POS  33952b07-859c-4c0a-8b1d-813a5f6b444c
# 15  153.05 -27.61             POS  d920de7f-959c-4d9a-aee5-930689a2f8cd
# 19  145.45 -37.74             POS  b5565fff-0333-4c74-a61a-56a074d0ec0f
# 20  153.41 -27.95             POS  f2ef6270-cf91-409f-a6a2-fbd6735ea500
#
#     merchant_code first_name  ...  age   merchant_suburb merchant_state  \
# 0             0.0      Diana  ...   26           Ashmore            QLD
# 2             0.0    Michael  ...   38            Sydney            NSW
# 4             0.0      Diana  ...   26     Mermaid Beach            QLD
# 6             0.0    Kristin  ...   43          Kalkallo            VIC
# 7             0.0    Kristin  ...   43         Melbourne            VIC
# 8             0.0      Tonya  ...   27            Yokine             WA
# 12            0.0      Tonya  ...   27  Cockburn Central             WA
# 15            0.0    Jeffrey  ...   30     Mount Ommaney            QLD
# 19            0.0   Kimberly  ...   24         Brunswick            VIC
# 20            0.0      Diana  ...   26         Byron Bay            NSW
#
#                       extraction amount                    transaction_id  \
# 0   2018-08-01T01:01:15.000+0000  16.25  a623070bfead4541a6b0fff8a09e706c
# 2   2018-08-01T01:26:15.000+0000   6.42  feb79e7ecd7048a5a36ec889d1a94270
# 4   2018-08-01T01:51:15.000+0000   3.25  329adf79878c4cf0aeb4188b4691c266
# 6   2018-08-01T02:23:04.000+0000  61.06  b79ca208099c4c28aa5dae966096d842
# 7   2018-08-01T04:11:25.000+0000  15.61  e1c4a50d6a0549cbb3710a62a2fa00d5
# 8   2018-08-01T04:40:00.000+0000  19.25  799e39eb2c1b411185424b0f2cd18bda
# 12  2018-08-01T06:06:40.000+0000   6.08  9ba4928260b24fbb8fb00f1f8d86b868
# 15  2018-08-01T07:20:48.000+0000  10.79  28347ba260d84f8d81ab70d9e901ea8e
# 19  2018-08-01T08:00:11.000+0000   7.37  2f77c3cbe847468bbf99f7f0cead69f9
# 20  2018-08-01T08:09:42.000+0000  14.10  1c12c9ad77894ef8b507fb091e41e928
#
#       country     customer_id merchant_long_lat movement
# 0   Australia  CUS-2487424745     153.38 -27.99    debit
# 2   Australia  CUS-2142601169     151.21 -33.87    debit
# 4   Australia  CUS-2487424745     153.44 -28.06    debit
# 6   Australia  CUS-4123612273     144.95 -37.53    debit
# 7   Australia  CUS-4123612273     144.96 -37.81    debit
# 8   Australia  CUS-3026014945      115.85 -31.9    debit
# 12  Australia  CUS-3026014945     115.86 -32.13    debit
# 15  Australia   CUS-860700529     152.94 -27.55    debit
# 19  Australia  CUS-3378712515     144.96 -37.78    debit
# 20  Australia  CUS-2487424745      153.6 -28.63    debit
#
# [10 rows x 23 columns]

# %%
['status','card_present_flag', 'bpay_biller_code', 'account' , 'currency' , 'long_lat', 'txn_description', 'merchant_id', 'merchant_code', 'first_name', 'age', 'merchant_suburb', 'merchant_state', 'extraction', 'amount'
'transaction_id', 'country', 'customer_id', 'merchant_long_lat', 'movement']
# Out:
# ['status',
#  'card_present_flag',
#  'bpay_biller_code',
#  'account',
#  'currency',
#  'long_lat',
#  'txn_description',
#  'merchant_id',
#  'merchant_code',
#  'first_name',
#  'age',
#  'merchant_suburb',
#  'merchant_state',
#  'extraction',
#  'amounttransaction_id',
#  'country',
#  'customer_id',
#  'merchant_long_lat',
#  'movement']

# %%
df6=df.query('txn_description == "POS" and amount > 100.0')
df6
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 49     authorized                1.0                0  ACC-2615038700
# 58     authorized                0.0                0  ACC-4258502723
# 159    authorized                0.0                0   ACC-847145727
# 164    authorized                1.0                0  ACC-3879258709
# 226    authorized                1.0                0  ACC-3536132544
# ...           ...                ...              ...             ...
# 11576  authorized                1.0                0   ACC-966140392
# 11834  authorized                1.0                0  ACC-2776252858
# 11840  authorized                0.0                0  ACC-3536132544
# 11958  authorized                1.0                0  ACC-2897221629
# 11973  authorized                1.0                0  ACC-1344825761
#
#       currency       long_lat txn_description  \
# 49         AUD  145.35 -38.03             POS
# 58         AUD  145.45 -37.74             POS
# 159        AUD  115.90 -31.92             POS
# 164        AUD  143.83 -37.66             POS
# 226        AUD  144.93 -37.79             POS
# ...        ...            ...             ...
# 11576      AUD  147.08 -37.97             POS
# 11834      AUD  144.95 -37.76             POS
# 11840      AUD  144.93 -37.79             POS
# 11958      AUD  150.90 -34.37             POS
# 11973      AUD  151.09 -33.91             POS
#
#                                 merchant_id  merchant_code first_name  ...  \
# 49     07df1647-c4aa-479b-a7c2-1952aafbc6bb            0.0      Emily  ...
# 58     e77e7118-9958-4ae0-8ecd-b705bde43c16            0.0   Kimberly  ...
# 159    e62c0cf2-08f3-42c5-bad4-6de138fd9351            0.0    Michael  ...
# 164    42ade571-5972-4160-9ecb-e0162a305fee            0.0    Natasha  ...
# 226    ec141b19-89cc-42cb-9c0b-4493ab9a80b5            0.0    Heather  ...
# ...                                     ...            ...        ...  ...
# 11576  7aa35faa-c607-489f-b7ea-226b095b16ee            0.0     Joseph  ...
# 11834  7a9c57e3-5d01-430c-bd41-6a6ff7739d49            0.0    Kristin  ...
# 11840  e7102f80-2949-4579-8e34-45a97474dcd9            0.0    Heather  ...
# 11958  d5635ec1-7e0d-40c1-a0ec-f560ad82d400            0.0      Scott  ...
# 11973  ddce202f-e1d4-4008-b949-c0bbd793eb2f            0.0      Sarah  ...
#
#        age  merchant_suburb merchant_state                    extraction  \
# 49      43  Dandenong South            VIC  2018-08-01T10:55:42.000+0000
# 58      24           Sydney            NSW  2018-08-01T11:45:34.000+0000
# 159     19       West Perth             WA  2018-08-02T07:20:44.000+0000
# 164     40          Belrose            NSW  2018-08-02T08:16:34.000+0000
# 226     41        Parkville            VIC  2018-08-02T15:10:15.000+0000
# ...    ...              ...            ...                           ...
# 11576   21        Melbourne            VIC  2018-10-28T02:54:47.000+0000
# 11834   43              Vic            VIC  2018-10-30T09:00:55.000+0000
# 11840   41          Highett            VIC  2018-10-30T09:55:57.000+0000
# 11958   23        East Ryde            NSW  2018-10-31T11:49:44.000+0000
# 11973   46      Surry Hills            NSW  2018-10-31T13:34:20.000+0000
#
#         amount                    transaction_id    country     customer_id  \
# 49      937.73  44806f4994f249e9a7411776530e0ff6  Australia  CUS-3255104878
# 58      109.51  fcb9829f70104a338b34cee4eb6cc9c8  Australia  CUS-3378712515
# 159    1692.56  dc4ae2d4b0ec4643bf04445eee0d60d8  Australia  CUS-1609060617
# 164     108.65  da7d50bf71c14c7f884a3328cff0467b  Australia   CUS-527400765
# 226     107.67  02e98a1a6fb94e2583dfd8a84bd152bc  Australia  CUS-2348881191
# ...        ...                               ...        ...             ...
# 11576   107.34  89514ba0ddf54f04beb210a00bda37c5  Australia   CUS-537508723
# 11834   111.30  d08703d9f71a4253a32d75ad4c29ac9d  Australia  CUS-4123612273
# 11840   109.68  4f5502701547461382ef6dce26846468  Australia  CUS-2348881191
# 11958   348.21  e4ea3360d90840a09a72ba2a34271618  Australia   CUS-511326734
# 11973   263.64  dc000af1a59b4892b23478446e9435e0  Australia  CUS-1499065773
#
#       merchant_long_lat movement
# 49        145.21 -38.03    debit
# 58        151.21 -33.87    debit
# 159       115.84 -31.95    debit
# 164        151.21 -33.7    debit
# 226        144.96 -37.8    debit
# ...                 ...      ...
# 11576     144.96 -37.82    debit
# 11834     145.31 -37.76    debit
# 11840     145.05 -37.95    debit
# 11958     151.13 -33.81    debit
# 11973     151.21 -33.88    debit
#
# [187 rows x 23 columns]

# %%
#  5 Top largest value of amount  
result = df.nlargest(5, 'amount')
result
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 2401       posted                0.0                0  ACC-1523339231
# 6529       posted                0.0                0  ACC-1523339231
# 10429      posted                0.0                0  ACC-1523339231
# 10430      posted                0.0                0  ACC-1523339231
# 10711  authorized                1.0                0   ACC-819621312
#
#       currency       long_lat txn_description  \
# 2401       AUD  115.83 -31.90      PAY/SALARY
# 6529       AUD  115.83 -31.90      PAY/SALARY
# 10429      AUD  115.83 -31.90      PAY/SALARY
# 10430      AUD  115.83 -31.90      PAY/SALARY
# 10711      AUD  145.04 -37.85             POS
#
#                                 merchant_id  merchant_code first_name  ...  \
# 2401                                      0            0.0        Tim  ...
# 6529                                      0            0.0        Tim  ...
# 10429                                     0            0.0        Tim  ...
# 10430                                     0            0.0        Tim  ...
# 10711  af835ef4-60b7-4283-9d9a-5d0a8ab9cd6f            0.0    Michele  ...
#
#        age merchant_suburb merchant_state                    extraction  \
# 2401    40               0              0  2018-08-20T13:00:00.000+0000
# 6529    40               0              0  2018-09-20T13:00:00.000+0000
# 10429   40               0              0  2018-10-19T13:00:00.000+0000
# 10430   40               0              0  2018-10-19T13:00:00.000+0000
# 10711   30  South Brisbane            QLD  2018-10-21T14:49:45.000+0000
#
#         amount                    transaction_id    country     customer_id  \
# 2401   8835.98  b608ce5142664a79af4fa071a886c8f7  Australia  CUS-1816693151
# 6529   8835.98  854ded55d0034ac8b9e91e16334768ca  Australia  CUS-1816693151
# 10429  8835.98  873a3f11d03d41a99c55a5b1a3850e1a  Australia  CUS-1816693151
# 10430  8835.98  d996300131a641c8bf25f86e1aef9bc6  Australia  CUS-1816693151
# 10711  7081.09  2a882afd1d1c4eb28c3b5ccba14e240d  Australia  CUS-1271030853
#
#       merchant_long_lat movement
# 2401                  0   credit
# 6529                  0   credit
# 10429                 0   credit
# 10430                 0   credit
# 10711     153.02 -27.48    debit
#
# [5 rows x 23 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
result.plot(kind='bar')

# %%
w= df.nsmallest(2, 'amount')
w
# Out:
#           status  card_present_flag bpay_biller_code         account currency  \
# 5395  authorized                0.0                0   ACC-211792489      AUD
# 6428  authorized                1.0                0  ACC-3541460373      AUD
#
#            long_lat txn_description                           merchant_id  \
# 5395  138.63 -34.93       SALES-POS  3b6372a5-9b14-4d98-bb58-92c215bca597
# 6428  145.00 -37.83             POS  a6a341db-200c-4833-a93d-893d18b019ea
#
#       merchant_code  first_name  ...  age merchant_suburb merchant_state  \
# 5395            0.0  Jacqueline  ...   30       Melbourne            VIC
# 6428            0.0     Jeffrey  ...   24       Southbank            VIC
#
#                         extraction amount                    transaction_id  \
# 5395  2018-09-12T09:02:37.000+0000    0.1  daab7b7e1e5c4503b87d96358d9b4bee
# 6428  2018-09-19T17:21:28.000+0000    0.1  392deeb7fff748f48b19ad95381e8aa2
#
#         country     customer_id merchant_long_lat movement
# 5395  Australia   CUS-497688347     144.96 -37.81    debit
# 6428  Australia  CUS-1433879684     144.96 -37.82    debit
#
# [2 rows x 23 columns]

# %% [markdown]
# ## **Build a simple regression model to predict**

# %% [markdown]
# # regression equation:
# # Y=a+bX+u (Simple Linear Regression)
# Where:
#
# Y = dependent variable(the variable that you are trying to predict )
#
# X = independent variable(the variable that you are using to predict Y )
#
# a = the intercept.
#
# b = the slope.
#
# u = the regression residual.

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (3.1.0)

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Divide Dataframe to Train and Test data

# %%
y = df.pop('age')
X = df
X_train,X_test,y_train,y_test = train_test_split(X.index,y,test_size=0.2, random_state=0)
X.iloc[X_train]
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 5348       posted                0.0                0  ACC-1424176027
# 8485   authorized                0.0                0  ACC-1903037542
# 8813       posted                0.0                0  ACC-1523339231
# 7755   authorized                1.0                0  ACC-1598451071
# 7037   authorized                1.0                0  ACC-3084464802
# ...           ...                ...              ...             ...
# 4859   authorized                0.0                0  ACC-1037050564
# 3264   authorized                0.0                0  ACC-4065652575
# 9845   authorized                1.0                0  ACC-1222300524
# 10799  authorized                1.0                0  ACC-3317636250
# 2732       posted                0.0                0   ACC-211792489
#
#       currency       long_lat txn_description  \
# 5348       AUD  151.08 -33.93         PAYMENT
# 8485       AUD  153.05 -27.61       SALES-POS
# 8813       AUD  115.83 -31.90      INTER BANK
# 7755       AUD  153.41 -27.95             POS
# 7037       AUD  145.15 -37.76       SALES-POS
# ...        ...            ...             ...
# 4859       AUD  153.10 -27.66       SALES-POS
# 3264       AUD  115.81 -31.82       SALES-POS
# 9845       AUD  151.23 -33.94       SALES-POS
# 10799      AUD  153.02 -27.66       SALES-POS
# 2732       AUD  138.63 -34.93         PAYMENT
#
#                                 merchant_id  merchant_code  first_name  \
# 5348                                      0            0.0      Donald
# 8485   6b9bea63-44b3-4cb3-893b-704116ebce00            0.0     Jeffrey
# 8813                                      0            0.0         Tim
# 7755   7deda505-d941-43ac-9d5e-f866d57dcc4e            0.0       Diana
# 7037   b0016a1a-83b4-410f-9d1b-f7417d7b4ae8            0.0       Susan
# ...                                     ...            ...         ...
# 4859   abceb6ed-6007-4ce8-b391-763bf0afe0cd            0.0      Rhonda
# 3264   be37f62b-6874-494d-9905-54d7e27b1eec            0.0       Lucas
# 9845   9980b7fe-3d5f-4aee-9ed0-74f4b050a175            0.0     Michael
# 10799  f7a4ce77-7c3e-4fde-afb5-456995ce97bc            0.0     Kenneth
# 2732                                      0            0.0  Jacqueline
#
#              date merchant_suburb merchant_state  \
# 5348    9/11/2018               0              0
# 8485    10/4/2018         Toowong            QLD
# 8813    10/7/2018               0              0
# 7755    9/29/2018      Helensvale            QLD
# 7037    9/24/2018       Melbourne            VIC
# ...           ...             ...            ...
# 4859     9/7/2018  South Brisbane            QLD
# 3264    8/26/2018           Perth             WA
# 9845   10/15/2018       Bankstown            NSW
# 10799  10/22/2018  Toowoomba City            QLD
# 2732    8/23/2018               0              0
#
#                          extraction  amount                    transaction_id  \
# 5348   2018-09-11T19:00:00.000+0000  186.00  c512103b059a437c83d4db49104d140c
# 8485   2018-10-04T21:20:52.000+0000   12.80  a589940a3338435b84d4395ab304d67f
# 8813   2018-10-07T06:00:00.000+0000   39.00  38d344a0472f43798d236cf239954868
# 7755   2018-09-29T10:56:27.000+0000   17.27  f5a687c9782d4e32b346d8ec6fb8652f
# 7037   2018-09-24T09:18:03.000+0000   41.67  46ced647a8514e778cf0905ba9bcfe44
# ...                             ...     ...                               ...
# 4859   2018-09-07T19:23:14.000+0000    6.55  9ba06a4a9ddd444589faa0165238f427
# 3264   2018-08-26T22:30:50.000+0000    5.64  9b68e324ab384d8d8b05812b4029af64
# 9845   2018-10-15T08:08:21.000+0000    9.82  7e074ea940da4f379dc18cf671b786be
# 10799  2018-10-22T09:32:31.000+0000    9.14  27eba3806d9b43b98587bf5c509ae578
# 2732   2018-08-23T06:00:00.000+0000   47.00  af642736a785409caf900e4f68ee4f16
#
#          country     customer_id merchant_long_lat movement
# 5348   Australia  CUS-3431016847                 0    debit
# 8485   Australia   CUS-860700529     152.99 -27.49    debit
# 8813   Australia  CUS-1816693151                 0    debit
# 7755   Australia  CUS-2487424745     153.34 -27.93    debit
# 7037   Australia  CUS-1928710999     144.96 -37.81    debit
# ...          ...             ...               ...      ...
# 4859   Australia  CUS-1614226872     153.02 -27.48    debit
# 3264   Australia  CUS-1117979751     115.86 -31.95    debit
# 9845   Australia  CUS-2142601169     151.04 -33.92    debit
# 10799  Australia  CUS-2738291516     151.95 -27.56    debit
# 2732   Australia   CUS-497688347                 0    debit
#
# [9634 rows x 20 columns]

# %%
from sklearn.linear_model import LinearRegression

X = X.apply(pd.to_numeric, errors='coerce')
y = y.apply(pd.to_numeric, errors='coerce')
X.fillna(0, inplace=True)
y.fillna(0, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
clf = LinearRegression().fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([30.10371512, 31.37220178, 30.10469635, ..., 30.1063433 ,
#        30.10954704, 30.10121523])

# %%
y_test = np.array(list(y_test))
y_pred = np.array(y_pred)
df4= pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})

# %%
print(X.shape)
(13807, 18)
print(y.shape)
(13807, 19)
# Out:
# (12043, 20)
# (12043,)
# (13807, 19)

# %%
plt.figure(2)
plt.scatter(y_test, X_test.iloc[:,0].values)

plt.figure(3)
plt.scatter(y_test, X_test.iloc[:,1].values)

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# # **Check the Linear Regression Performance**

# %% [markdown]
# The Mean Squared Error (MSE) is a measure of how close a fitted line is to data points.

# %%
from sklearn.metrics import mean_squared_error
import math
print(mean_squared_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 105.43795221717673
# 10.268298409044057

# %% [markdown]
# # Accuracy (e.g. classification accuracy) is a measure for classification, not regression. We cannot calculate accuracy for a regression model.

# %%
import seaborn as sns

# %%
sns.countplot(df['first_name'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Decision Tree**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state=42)

# %%
import pandas as pd # data processing
import numpy as np # working with arrays
import matplotlib.pyplot as plt # visualization
from termcolor import colored as cl # text customization
from sklearn.tree import DecisionTreeClassifier as dtc # tree algorithm
from sklearn.model_selection import train_test_split # splitting the data
from sklearn.metrics import accuracy_score # model precision
from sklearn.tree import plot_tree # tree diagram

# %%
print(cl('X_train shape : {}'.format(X_train.shape), attrs = ['bold'], color = 'blue'))
print(cl('X_test shape : {}'.format(X_test.shape), attrs = ['bold'], color = 'yellow'))
print(cl('y_train shape : {}'.format(y_train.shape), attrs = ['bold'], color = 'green'))
print(cl('y_test shape : {}'.format(y_test.shape), attrs = ['bold'], color = 'red'))
# Out:
# X_train shape : (8430, 20)
# X_test shape : (3613, 20)
# y_train shape : (8430,)
# y_test shape : (3613,)

# %%
model = dtc(criterion = 'entropy', max_depth = 4)
model.fit(X_train, y_train)

pred_model = model.predict(X_test)

print(cl('Accuracy of the model is {:.0%}'.format(accuracy_score(y_test, pred_model)), attrs = ['bold']))
# Out:
# Accuracy of the model is 9%

# %% [markdown]
# To increase the prediction, we can add more data or employ another multi model

# %%
from sklearn import tree
import graphviz
plot_tree(model, 
          filled = True, 
          rounded = True)

plt.savefig('tree_visualization.png')

# %%
from sklearn.tree import export_text
r = export_text(model)
print(r)
# Out:
# |--- feature_14 <= 15.23
# |   |--- feature_14 <= 6.15
# |   |   |--- feature_14 <= 5.99
# |   |   |   |--- feature_14 <= 5.02
# |   |   |   |   |--- class: 26
# |   |   |   |--- feature_14 >  5.02
# |   |   |   |   |--- class: 26
# |   |   |--- feature_14 >  5.99
# |   |   |   |--- feature_14 <= 6.09
# |   |   |   |   |--- class: 19
# |   |   |   |--- feature_14 >  6.09
# |   |   |   |   |--- class: 26
# |   |--- feature_14 >  6.15
# |   |   |--- feature_14 <= 14.94
# |   |   |   |--- feature_14 <= 10.52
# |   |   |   |   |--- class: 26
# |   |   |   |--- feature_14 >  10.52
# |   |   |   |   |--- class: 26
# |   |   |--- feature_14 >  14.94
# |   |   |   |--- feature_14 <= 15.05
# |   |   |   |   |--- class: 20
# |   |   |   |--- feature_14 >  15.05
# |   |   |   |   |--- class: 20
# |--- feature_14 >  15.23
# |   |--- feature_14 <= 32.91
# |   |   |--- feature_14 <= 20.01
# |   |   |   |--- feature_14 <= 19.99
# |   |   |   |   |--- class: 26
# |   |   |   |--- feature_14 >  19.99
# |   |   |   |   |--- class: 26
# |   |   |--- feature_14 >  20.01
# |   |   |   |--- feature_14 <= 25.98
# |   |   |   |   |--- class: 40
# |   |   |   |--- feature_14 >  25.98
# |   |   |   |   |--- class: 21
# |   |--- feature_14 >  32.91
# |   |   |--- feature_14 <= 33.05
# |   |   |   |--- feature_14 <= 33.00
# |   |   |   |   |--- class: 35
# |   |   |   |--- feature_14 >  33.00
# |   |   |   |   |--- class: 19
# |   |   |--- feature_14 >  33.05
# |   |   |   |--- feature_14 <= 40.01
# |   |   |   |   |--- class: 19
# |   |   |   |--- feature_14 >  40.01
# |   |   |   |   |--- class: 38

# %% [markdown]
# Decision trees supports non linearity, where LR supports only linear solutions. When there are large number of features with less data-sets(with low noise), linear regressions may outperform Decision trees/random forests. In general cases, Decision trees will be having better average accuracy.
